# %%
# !pip install numpy

# %%
import numpy as np

# %%
import json
#open the kaggle.json in read mode
with open("../artifacts/kaggle.json", "r") as file:
    #take to a variable
    data = json.load(file)

# %%
#read the data in data variable
data
# Out:
# {'username': 'sarasii22', 'key': '1e3af8bb621e7ae88d10aedef501e331'}

# %%
#install kaggle library
# !pip install kaggle
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [python-slugify]
#    -------------------------- ------------- 2/3 [kaggle]
#    -------------------------- ------------- 2/3 [kaggle]
#    ---------------------------------------- 3/3 [kaggle]
#
# ...

# %%
#create os
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
#connect with kaggle website
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
#download the data set
#using this api we can donwload any dataset using dataset name
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
#unzip the downloaded dataset importing zipfile library using ZipFile method
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
