# %%
# !pip install numpy

# %%
import numpy as np

# %%
pip install kagglehub
# Out:
# ...
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [protobuf]
#    ---------- ----------------------------- 1/4 [protobuf]
#    ---------- ----------------------------- 1/4 [protobuf]
#    ---------- ----------------------------- 1/4 [protobuf]
#    ---------- ----------------------------- 1/4 [protobuf]
#    -------------------- ------------------- 2/4 [kagglesdk]
#    -------------------- ------------------- 2/4 [kagglesdk]
#    -------------------- ------------------- 2/4 [kagglesdk]
#    -------------------- ------------------- 2/4 [kagglesdk]
#    -------------------- ------------------- 2/4 [kagglesdk]
#    -------------------- ------------------- 2/4 [kagglesdk]
#    ------------------------------ --------- 3/4 [kagglehub]
#    ------------------------------ --------- 3/4 [kagglehub]
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dineshpiyasamara/sentiment-analysis-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████| 460k/460k [00:01<00:00, 374kB/s]
# Extracting files...
# Path to dataset files: C:\Users\saras\.cache\kagglehub\datasets\dineshpiyasamara\sentiment-analysis-dataset\versions\1

# %%
import os

path = r"C:\Users\saras\.cache\kagglehub\datasets\dineshpiyasamara\sentiment-analysis-dataset\versions\1"

print(os.listdir(path))
# Out:
# ['sentiment_analysis.csv']
